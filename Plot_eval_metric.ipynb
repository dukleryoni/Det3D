# %%
import json
import numpy as np
import matplotlib.pyplot as plt
import pandas

# %%
import os
os.getcwd()
# Out:
# '/home/image/ohs/Det3D'

# %%
file_dir ="/home/image/ohs/Det3D/experiments/hpc_experiments/baselines/ohs/"
file_name = file_dir+ "infos_val_10sweeps_repeat_withvelo.json"

# %%
with open(file_name) as f:
    data = json.load(f)

# %%
print(data)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
data['results']['fd8420396768425eabec9bdddf7e64b6']
# Out:
# [{'sample_token': 'fd8420396768425eabec9bdddf7e64b6',
#   'translation': [238.5926256443347, 913.61343441569, 0.8161877920829381],
#   'size': [1.8520252704620361, 4.525705337524414, 1.5183322429656982],
#   'rotation': [-0.045633724556023096,
#    -0.014572803872677172,
#    -0.004903109338066232,
#    -0.9988399051345784],
#   'velocity': [0.0, 0.0],
#   'detection_name': 'car',
#   'detection_score': 0.8689945936203003,
#   'attribute_name': 'vehicle.parked'},
#  {'sample_token': 'fd8420396768425eabec9bdddf7e64b6',
#   'translation': [245.36525208848767, 919.9379084333501, 0.7954051678016938],
#   'size': [1.8523125648498535, 4.507655143737793, 1.5571657419204712],
#   'rotation': [0.9545747088493256,
#    -0.008440195694911572,
#    0.012851855528449703,
#    -0.2975747269701083],
#   'velocity': [0.0, 0.0],
#   'detection_name': 'car',
#   'detection_score': 0.8107393980026245,
#   'attribute_name': 'vehicle.parked'},
#  {'sample_token': 'fd8420396768425eabec9bdddf7e64b6',
# ...
